# %%
# Imports
import sys, os, csv
print("Python executable:", sys.executable)
print("Python version:", sys.version.splitlines()[0])
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Check dataset path
DATA_PATH = os.path.join("data", "full_dataset-release.csv")
print("Expected CSV path:", DATA_PATH)
print("File exists:", os.path.exists(DATA_PATH))
if os.path.exists(DATA_PATH):
    print("Size (bytes):", os.path.getsize(DATA_PATH))
else:
    print("File is missing at location ", DATA_PATH)

# Display settings
print("Setting up display options...")
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", "{:,.4f}".format)
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
print("Display options set.")

# Load dataset
print("Loading dataset...")
DATA_PATH = Path("data") / "full_dataset-release.csv"
df = pd.read_csv(
    DATA_PATH,
    quoting=csv.QUOTE_ALL,
    encoding='utf-8',
    on_bad_lines='skip',
    engine='python'
)
print("Loaded:", DATA_PATH, "shape:", df.shape)
print("Dataset loaded.")

# Quick peek
display(df.head())
display(df.tail())

# Data cleaning
print("Cleaning data...")
# Clean column names
df.columns = df.columns.str.strip().str.replace(r"[\r\n]+", "", regex=True)
# Clean all string columns (especially TWEET)
df = df.apply(lambda col: col.str.replace(r"[\r\n]+", " ", regex=True).str.strip() if col.dtype == "object" else col)
# Convert DATE column
df["DATE"] = pd.to_datetime(df["DATE"], format="%d/%m/%Y", errors="coerce")
# Drop duplicates and rows missing key info
df.drop_duplicates(inplace=True)
df.dropna(subset=["DATE", "STOCK", "LAST_PRICE"], inplace=True)
# Convert numeric columns
numeric_cols = df.columns.drop(["TWEET", "STOCK", "DATE"])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors="coerce")
# Add sentiment label
df["LSTM_SENTIMENT"] = df["LSTM_POLARITY"].map({-1: "Negative", 0: "Neutral", 1: "Positive"})
# Save clean CSV
df.to_csv("data/cleaned_data.csv", index=False, lineterminator="\n")
print("Data cleaned.")

print("Null Tweets - \n", df[df["TWEET"].isnull()])
print("DataFrame shape:", df.shape)
print("Columns ", df.columns.tolist())
print("Info", df.info())
print("Describe", df.describe(include="all").T)
print("Head ", df.head())
print("Tail ", df.tail())

# Info & summary
print("\nDataFrame.info():")
display(df.info(verbose=True))

print("\nDescribe (numeric):")
display(df.describe().T)

print("\nDescribe (all):")
display(df.describe(include="all").T)

# Missing values
missing = df.isnull().sum().sort_values(ascending=False)
missing_pct = (missing / len(df) * 100).round(3)
missing_tbl = pd.concat([missing, missing_pct], axis=1)
missing_tbl.columns = ["missing_count", "missing_pct"]
display(missing_tbl[missing_tbl["missing_count"] > 0])

# Unique values and potential identifiers
unique_counts = df.nunique(dropna=False).sort_values()
display(unique_counts.to_frame(name="unique_count").tail(30))

# Duplicates
dups = df.duplicated().sum()
print(f"\nDuplicate rows: {dups}")
if dups:
    display(df[df.duplicated(keep=False)].head())

# Data types
dtypes = df.dtypes.value_counts()
print("\nData types distribution:")
display(dtypes)

# Detect and parse probable datetime columns (names containing 'date' or 'time')
date_candidates = [c for c in df.columns if ("date" in c.lower() or "time" in c.lower())]
parsed_dates = {}
for c in date_candidates:
    try:
        parsed = pd.to_datetime(df[c], errors="coerce", infer_datetime_format=True)
        non_null = parsed.notna().sum()
        if non_null:
            parsed_dates[c] = {"parsed_non_null": int(non_null), "min": parsed.min(), "max": parsed.max()}
            df[c + "_parsed"] = parsed
    except Exception:
        pass
if parsed_dates:
    print("\nParsed date/time candidates:")
    display(pd.DataFrame(parsed_dates).T)
else:
    print("\nNo parseable date/time columns detected by heuristic.")

# Numeric columns EDA: histograms and skew
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
print(f"\nNumeric columns ({len(num_cols)}): {num_cols[:20]}")
if num_cols:
    sample_nums = num_cols if len(num_cols) <= 12 else num_cols[:12]
    df[sample_nums].hist(bins=30, layout=(int(np.ceil(len(sample_nums)/3)), 3), figsize=(12, 8))
    plt.tight_layout()
    plt.show()

    skewness = df[num_cols].skew().sort_values(ascending=False)
    display(skewness.to_frame(name="skew").head(20))

    # Correlation heatmap (limit size)
    corr = df[num_cols].corr()
    if corr.shape[0] <= 50:
        mask = np.triu(np.ones_like(corr, dtype=bool))
        plt.figure(figsize=(min(14, corr.shape[0]), min(12, corr.shape[0])))
        sns.heatmap(corr, mask=mask, cmap="coolwarm", center=0, annot=False, fmt=".2f")
        plt.title("Numeric correlation matrix")
        plt.show()
    else:
        print("Too many numeric columns to plot full correlation matrix (>{} cols).".format(50))

# Categorical columns: top value counts
cat_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
print(f"\nCategorical columns ({len(cat_cols)}): {cat_cols[:20]}")
for c in cat_cols[:20]:
    vc = df[c].value_counts(dropna=False).head(10)
    print(f"\nTop values for {c}:")
    display(vc)

# Save small EDA artifacts
out_dir = Path("eda_outputs")
out_dir.mkdir(exist_ok=True)
missing_tbl.to_csv(out_dir / "missing_summary.csv")
unique_counts.to_frame("unique_count").to_csv(out_dir / "unique_counts.csv")
print(f"\nSaved missing_summary.csv and unique_counts.csv to {out_dir}/")

# Final sample
print("\nRandom sample:")
display(df.sample(min(10, len(df)), random_state=42))

# Keep df in memory for further analysis
# Out:
# Python executable: c:\Users\owner\AppData\Local\Programs\Python\Python311\python.exe
# Python version: 3.11.8 (tags/v3.11.8:db85d51, Feb  6 2024, 22:03:32) [MSC v.1937 64 bit (AMD64)]
# Expected CSV path: data\full_dataset-release.csv
# File exists: True
# Size (bytes): 136278819
# Setting up display options...
# Display options set.
# Loading dataset...
# Loaded: data\full_dataset-release.csv shape: (1356848, 14)
# Dataset loaded.
#     ID                                              TWEET       STOCK  \
# 0    0  RT @robertoglezcano: @amazon  #Patents Show Fl...        None
# 1  NaN                                             Amazon  31/01/2017
# 2    1  @FAME95FM1 Jamaicans make money with @Payoneer...      PayPal
# 3    2  @CBSi Jamaicans make money with @Payoneer @Pay...      PayPal
# 4    3  @Hitz92fm Jamaicans make money with @Payoneer ...      PayPal
#
#          DATE  LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  \
# 0        None         NaN           NaN           NaN           NaN
# 1      823.48      0.0084        0.0149        0.0149       -0.0013
# 2  31/01/2017     39.7800        0.0020        0.0123        0.0123
# 3  31/01/2017     39.7800        0.0020        0.0123        0.0123
# 4  31/01/2017     39.7800        0.0020        0.0123        0.0123
#
#     7_DAY_RETURN      PX_VOLUME  VOLATILITY_10D  VOLATILITY_30D  \
# 0            NaN            NaN             NaN             NaN
# 1 3,137,196.0000        13.4470         16.9920          1.0000
# 2         0.0548 9,100,057.0000         18.7690         16.0990
# 3         0.0548 9,100,057.0000         18.7690         16.0990
# 4         0.0548 9,100,057.0000         18.7690         16.0990
#
#    LSTM_POLARITY  TEXTBLOB_POLARITY
# 0            NaN                NaN
# 1         0.0000                NaN
# 2        -1.0000             0.0000
# 3         1.0000             0.0000
# 4        -1.0000             0.0000
#              ID                                              TWEET  \
# 1356843     NaN                                             PayPal
# 1356844  862229  RT @RifatJawaid: Deceased Apple executive's br...
# 1356845     NaN                                              Apple
# 1356846  862230  Flat 6000 INR cashback on HDFC debit and credi...
# 1356847     NaN                                            Samsung
#
#               STOCK     DATE  LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  \
# 1356843  30/09/2018    87.84      0.0000        0.0000        0.0131
# 1356844        None     None         NaN           NaN           NaN
# 1356845  30/09/2018   225.74      0.0000        0.0000       -0.0035
# 1356846        None     None         NaN           NaN           NaN
# 1356847  30/09/2018  46450.0      0.0000        0.0000        0.0226
#
#          3_DAY_RETURN    7_DAY_RETURN  PX_VOLUME  VOLATILITY_10D  \
# 1356843        0.0316  7,920,916.0000    15.7540         23.1310
# 1356844           NaN             NaN        NaN             NaN
# 1356845       -0.0358 22,929,364.0000    15.8410         20.0650
# 1356846           NaN             NaN        NaN             NaN
# 1356847        0.0205 11,270,515.0000    31.7620         26.9700
#
#          VOLATILITY_30D  LSTM_POLARITY  TEXTBLOB_POLARITY
# 1356843         -1.0000         0.2000                NaN
# 1356844             NaN            NaN                NaN
# 1356845          1.0000         0.0000                NaN
# 1356846             NaN            NaN                NaN
# 1356847         -1.0000        -0.0312                NaN
# Cleaning data...
# Data cleaned.
# Null Tweets -
#  Empty DataFrame
# Columns: [ID, TWEET, STOCK, DATE, LAST_PRICE, 1_DAY_RETURN, 2_DAY_RETURN, 3_DAY_RETURN, 7_DAY_RETURN, PX_VOLUME, VOLATILITY_10D, VOLATILITY_30D, LSTM_POLARITY, TEXTBLOB_POLARITY, LSTM_SENTIMENT]
# Index: []
# DataFrame shape: (367666, 15)
# Columns  ['ID', 'TWEET', 'STOCK', 'DATE', 'LAST_PRICE', '1_DAY_RETURN', '2_DAY_RETURN', '3_DAY_RETURN', '7_DAY_RETURN', 'PX_VOLUME', 'VOLATILITY_10D', 'VOLATILITY_30D', 'LSTM_POLARITY', 'TEXTBLOB_POLARITY', 'LSTM_SENTIMENT']
# <class 'pandas.core.frame.DataFrame'>
# Index: 367666 entries, 2 to 1356841
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 367666 non-null  int64
#  1   TWEET              367666 non-null  object
#  2   STOCK              367666 non-null  object
#  3   DATE               367666 non-null  datetime64[ns]
#  4   LAST_PRICE         367666 non-null  float64
#  5   1_DAY_RETURN       367666 non-null  float64
#  6   2_DAY_RETURN       367666 non-null  float64
#  7   3_DAY_RETURN       367666 non-null  float64
#  8   7_DAY_RETURN       367666 non-null  float64
#  9   PX_VOLUME          367666 non-null  float64
#  10  VOLATILITY_10D     367666 non-null  float64
#  11  VOLATILITY_30D     367621 non-null  float64
#  12  LSTM_POLARITY      367666 non-null  float64
#  13  TEXTBLOB_POLARITY  367665 non-null  float64
#  14  LSTM_SENTIMENT     367666 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(1), object(3)
# memory usage: 44.9+ MB
# Info None
# Describe                          count  unique  \
# ID                367,666.0000     NaN
# TWEET                   367666  206462
# STOCK                   367666     101
# DATE                    367666     NaN
# LAST_PRICE        367,666.0000     NaN
# 1_DAY_RETURN      367,666.0000     NaN
# 2_DAY_RETURN      367,666.0000     NaN
# 3_DAY_RETURN      367,666.0000     NaN
# 7_DAY_RETURN      367,666.0000     NaN
# PX_VOLUME         367,666.0000     NaN
# VOLATILITY_10D    367,666.0000     NaN
# VOLATILITY_30D    367,621.0000     NaN
# LSTM_POLARITY     367,666.0000     NaN
# TEXTBLOB_POLARITY 367,665.0000     NaN
# LSTM_SENTIMENT          367666       2
#
#                                                                  top    freq  \
# ID                                                               NaN     NaN
# TWEET              RT @BTS_twt: RM - mono. Soundcloud: https://t....    2619
# STOCK                                                           Ford   52198
# DATE                                                             NaN     NaN
# LAST_PRICE                                                       NaN     NaN
# 1_DAY_RETURN                                                     NaN     NaN
# 2_DAY_RETURN                                                     NaN     NaN
# 3_DAY_RETURN                                                     NaN     NaN
# 7_DAY_RETURN                                                     NaN     NaN
# PX_VOLUME                                                        NaN     NaN
# VOLATILITY_10D                                                   NaN     NaN
# VOLATILITY_30D                                                   NaN     NaN
# LSTM_POLARITY                                                    NaN     NaN
# TEXTBLOB_POLARITY                                                NaN     NaN
# LSTM_SENTIMENT                                              Positive  206094
#
#                                             mean                  min  \
# ID                                  457,424.7871               1.0000
# TWEET                                        NaN                  NaN
# STOCK                                        NaN                  NaN
# DATE               2018-07-08 18:11:24.660534784  2017-01-31 00:00:00
# LAST_PRICE                            1,679.4142               3.0100
# 1_DAY_RETURN                              0.0008              -0.1467
# 2_DAY_RETURN                              0.0015              -0.1736
# 3_DAY_RETURN                              0.0015              -0.1779
# 7_DAY_RETURN                              0.0034              -0.2050
# PX_VOLUME                        17,640,603.6962               1.0000
# VOLATILITY_10D                           24.5670               0.6190
# VOLATILITY_30D                           25.0333               4.5250
# LSTM_POLARITY                             0.1211              -1.0000
# TEXTBLOB_POLARITY                         0.0762              -1.0000
# LSTM_SENTIMENT                               NaN                  NaN
#
#                                    25%                  50%  \
# ID                        249,901.2500         464,006.5000
# TWEET                              NaN                  NaN
# STOCK                              NaN                  NaN
# DATE               2018-08-01 00:00:00  2018-09-03 00:00:00
# LAST_PRICE                     59.0000             169.2500
# 1_DAY_RETURN                   -0.0056               0.0000
# 2_DAY_RETURN                   -0.0091               0.0000
# 3_DAY_RETURN                   -0.0112              -0.0002
# 7_DAY_RETURN                   -0.0219              -0.0011
# PX_VOLUME               2,963,133.0000       8,975,955.0000
# VOLATILITY_10D                 14.9360              20.5170
# VOLATILITY_30D                 18.2600              22.2420
# LSTM_POLARITY                  -1.0000               1.0000
# TEXTBLOB_POLARITY               0.0000               0.0000
# LSTM_SENTIMENT                     NaN                  NaN
#
#                                    75%                  max             std
# ID                        677,443.7500         862,227.0000    247,562.4589
# TWEET                              NaN                  NaN             NaN
# STOCK                              NaN                  NaN             NaN
# DATE               2018-09-22 00:00:00  2018-10-31 00:00:00             NaN
# LAST_PRICE                  1,159.8300         165,500.0000      7,133.2535
# 1_DAY_RETURN                    0.0044               0.2340          0.0182
# 2_DAY_RETURN                    0.0097               0.2436          0.0226
# 3_DAY_RETURN                    0.0135               0.2436          0.0268
# 7_DAY_RETURN                    0.0261               0.2671          0.0422
# PX_VOLUME              25,924,569.0000     314,833,202.0000 20,390,217.0190
# VOLATILITY_10D                 27.2670             124.1370         17.5317
# VOLATILITY_30D                 27.3880              87.6850         12.2193
# LSTM_POLARITY                   1.0000               1.0000          0.9926
# TEXTBLOB_POLARITY               0.1500               1.0000          0.2610
# LSTM_SENTIMENT                     NaN                  NaN             NaN
# Head      ID                                              TWEET      STOCK  \
# 2    1  @FAME95FM1 Jamaicans make money with @Payoneer...     PayPal
# 3    2  @CBSi Jamaicans make money with @Payoneer @Pay...     PayPal
# 4    3  @Hitz92fm Jamaicans make money with @Payoneer ...     PayPal
# 11   7  RT @nikitakhara: Thank you, @Starbucks CEO for...  Starbucks
# 20  12  @gawker Jamaicans make money with @Payoneer @P...     PayPal
#
#          DATE  LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  \
# 2  2017-01-31     39.7800        0.0020        0.0123        0.0123
# 3  2017-01-31     39.7800        0.0020        0.0123        0.0123
# 4  2017-01-31     39.7800        0.0020        0.0123        0.0123
# 11 2017-01-31     55.2200        0.0123        0.0163        0.0163
# 20 2017-01-31     39.7800        0.0020        0.0123        0.0123
#
#     7_DAY_RETURN       PX_VOLUME  VOLATILITY_10D  VOLATILITY_30D  \
# 2         0.0548  9,100,057.0000         18.7690         16.0990
# 3         0.0548  9,100,057.0000         18.7690         16.0990
# 4         0.0548  9,100,057.0000         18.7690         16.0990
# 11        0.0583 14,307,985.0000         23.9160         17.2980
# 20        0.0548  9,100,057.0000         18.7690         16.0990
#
#     LSTM_POLARITY  TEXTBLOB_POLARITY LSTM_SENTIMENT
# 2         -1.0000             0.0000       Negative
# 3          1.0000             0.0000       Positive
# 4         -1.0000             0.0000       Negative
# 11         1.0000             0.2000       Positive
# 20        -1.0000             0.0000       Negative
# Tail               ID                                              TWEET   STOCK  \
# 1356819  862214  RT @rmbyrne: Do you have any colleagues who th...  Google
# 1356820  862215  RT @AnnCoulter: Item No. 3 for FBI to investig...    Ford
# 1356829  862220  RT @radiodisney: Tune in to the Radio Disney I...  Disney
# 1356834  862223  Rockets Fall at Fresno State, 49-27; Return Ho...    Next
# 1356841  862227  RT @radiodisney: Tune in to the Radio Disney I...  Disney
#
#               DATE  LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  \
# 1356819 2018-09-30  1,207.0800        0.0000        0.0000        0.0002
# 1356820 2018-09-30      9.2500        0.0000        0.0000       -0.0022
# 1356829 2018-09-30    116.9400        0.0000        0.0000       -0.0077
# 1356834 2018-09-30  5,494.0000        0.0000        0.0000       -0.0295
# 1356841 2018-09-30    116.9400        0.0000        0.0000       -0.0077
#
#          7_DAY_RETURN       PX_VOLUME  VOLATILITY_10D  VOLATILITY_30D  \
# 1356819       -0.0290  1,780,759.0000         15.0050         17.5880
# 1356820        0.0649 30,987,233.0000         23.4920         22.9890
# 1356829       -0.0559  7,366,846.0000         15.2320         13.2300
# 1356834       -0.0535    729,746.0000         51.1570         29.3830
# 1356841       -0.0559  7,366,846.0000         15.2320         13.2300
#
#          LSTM_POLARITY  TEXTBLOB_POLARITY LSTM_SENTIMENT
# 1356819        -1.0000            -0.0625       Negative
# 1356820        -1.0000             0.0000       Negative
# 1356829         1.0000             0.0000       Positive
# 1356834         1.0000             0.0000       Positive
# 1356841         1.0000             0.0000       Positive
#
# DataFrame.info():
# <class 'pandas.core.frame.DataFrame'>
# Index: 367666 entries, 2 to 1356841
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 367666 non-null  int64
#  1   TWEET              367666 non-null  object
#  2   STOCK              367666 non-null  object
#  3   DATE               367666 non-null  datetime64[ns]
#  4   LAST_PRICE         367666 non-null  float64
#  5   1_DAY_RETURN       367666 non-null  float64
#  6   2_DAY_RETURN       367666 non-null  float64
#  7   3_DAY_RETURN       367666 non-null  float64
#  8   7_DAY_RETURN       367666 non-null  float64
#  9   PX_VOLUME          367666 non-null  float64
#  10  VOLATILITY_10D     367666 non-null  float64
#  11  VOLATILITY_30D     367621 non-null  float64
#  12  LSTM_POLARITY      367666 non-null  float64
#  13  TEXTBLOB_POLARITY  367665 non-null  float64
#  14  LSTM_SENTIMENT     367666 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(1), object(3)
# memory usage: 44.9+ MB
# None
# Describe (numeric):
#                          count                           mean  \
# ID                367,666.0000                   457,424.7871
# DATE                    367666  2018-07-08 18:11:24.660534784
# LAST_PRICE        367,666.0000                     1,679.4142
# 1_DAY_RETURN      367,666.0000                         0.0008
# 2_DAY_RETURN      367,666.0000                         0.0015
# 3_DAY_RETURN      367,666.0000                         0.0015
# 7_DAY_RETURN      367,666.0000                         0.0034
# PX_VOLUME         367,666.0000                17,640,603.6962
# VOLATILITY_10D    367,666.0000                        24.5670
# VOLATILITY_30D    367,621.0000                        25.0333
# LSTM_POLARITY     367,666.0000                         0.1211
# TEXTBLOB_POLARITY 367,665.0000                         0.0762
#
#                                    min                  25%  \
# ID                              1.0000         249,901.2500
# DATE               2017-01-31 00:00:00  2018-08-01 00:00:00
# LAST_PRICE                      3.0100              59.0000
# 1_DAY_RETURN                   -0.1467              -0.0056
# 2_DAY_RETURN                   -0.1736              -0.0091
# 3_DAY_RETURN                   -0.1779              -0.0112
# 7_DAY_RETURN                   -0.2050              -0.0219
# PX_VOLUME                       1.0000       2,963,133.0000
# VOLATILITY_10D                  0.6190              14.9360
# VOLATILITY_30D                  4.5250              18.2600
# LSTM_POLARITY                  -1.0000              -1.0000
# TEXTBLOB_POLARITY              -1.0000               0.0000
#
#                                    50%                  75%  \
# ID                        464,006.5000         677,443.7500
# DATE               2018-09-03 00:00:00  2018-09-22 00:00:00
# LAST_PRICE                    169.2500           1,159.8300
# 1_DAY_RETURN                    0.0000               0.0044
# 2_DAY_RETURN                    0.0000               0.0097
# 3_DAY_RETURN                   -0.0002               0.0135
# 7_DAY_RETURN                   -0.0011               0.0261
# PX_VOLUME               8,975,955.0000      25,924,569.0000
# VOLATILITY_10D                 20.5170              27.2670
# VOLATILITY_30D                 22.2420              27.3880
# LSTM_POLARITY                   1.0000               1.0000
# TEXTBLOB_POLARITY               0.0000               0.1500
#
#                                    max             std
# ID                        862,227.0000    247,562.4589
# DATE               2018-10-31 00:00:00             NaN
# LAST_PRICE                165,500.0000      7,133.2535
# 1_DAY_RETURN                    0.2340          0.0182
# 2_DAY_RETURN                    0.2436          0.0226
# 3_DAY_RETURN                    0.2436          0.0268
# 7_DAY_RETURN                    0.2671          0.0422
# PX_VOLUME             314,833,202.0000 20,390,217.0190
# VOLATILITY_10D                124.1370         17.5317
# VOLATILITY_30D                 87.6850         12.2193
# LSTM_POLARITY                   1.0000          0.9926
# TEXTBLOB_POLARITY               1.0000          0.2610
# Describe (all):
#                          count  unique  \
# ID                367,666.0000     NaN
# TWEET                   367666  206462
# STOCK                   367666     101
# DATE                    367666     NaN
# LAST_PRICE        367,666.0000     NaN
# 1_DAY_RETURN      367,666.0000     NaN
# 2_DAY_RETURN      367,666.0000     NaN
# 3_DAY_RETURN      367,666.0000     NaN
# 7_DAY_RETURN      367,666.0000     NaN
# PX_VOLUME         367,666.0000     NaN
# VOLATILITY_10D    367,666.0000     NaN
# VOLATILITY_30D    367,621.0000     NaN
# LSTM_POLARITY     367,666.0000     NaN
# TEXTBLOB_POLARITY 367,665.0000     NaN
# LSTM_SENTIMENT          367666       2
#
#                                                                  top    freq  \
# ID                                                               NaN     NaN
# TWEET              RT @BTS_twt: RM - mono. Soundcloud: https://t....    2619
# STOCK                                                           Ford   52198
# DATE                                                             NaN     NaN
# LAST_PRICE                                                       NaN     NaN
# 1_DAY_RETURN                                                     NaN     NaN
# 2_DAY_RETURN                                                     NaN     NaN
# 3_DAY_RETURN                                                     NaN     NaN
# 7_DAY_RETURN                                                     NaN     NaN
# PX_VOLUME                                                        NaN     NaN
# VOLATILITY_10D                                                   NaN     NaN
# VOLATILITY_30D                                                   NaN     NaN
# LSTM_POLARITY                                                    NaN     NaN
# TEXTBLOB_POLARITY                                                NaN     NaN
# LSTM_SENTIMENT                                              Positive  206094
#
#                                             mean                  min  \
# ID                                  457,424.7871               1.0000
# TWEET                                        NaN                  NaN
# STOCK                                        NaN                  NaN
# DATE               2018-07-08 18:11:24.660534784  2017-01-31 00:00:00
# LAST_PRICE                            1,679.4142               3.0100
# 1_DAY_RETURN                              0.0008              -0.1467
# 2_DAY_RETURN                              0.0015              -0.1736
# 3_DAY_RETURN                              0.0015              -0.1779
# 7_DAY_RETURN                              0.0034              -0.2050
# PX_VOLUME                        17,640,603.6962               1.0000
# VOLATILITY_10D                           24.5670               0.6190
# VOLATILITY_30D                           25.0333               4.5250
# LSTM_POLARITY                             0.1211              -1.0000
# TEXTBLOB_POLARITY                         0.0762              -1.0000
# LSTM_SENTIMENT                               NaN                  NaN
#
#                                    25%                  50%  \
# ID                        249,901.2500         464,006.5000
# TWEET                              NaN                  NaN
# STOCK                              NaN                  NaN
# DATE               2018-08-01 00:00:00  2018-09-03 00:00:00
# LAST_PRICE                     59.0000             169.2500
# 1_DAY_RETURN                   -0.0056               0.0000
# 2_DAY_RETURN                   -0.0091               0.0000
# 3_DAY_RETURN                   -0.0112              -0.0002
# 7_DAY_RETURN                   -0.0219              -0.0011
# PX_VOLUME               2,963,133.0000       8,975,955.0000
# VOLATILITY_10D                 14.9360              20.5170
# VOLATILITY_30D                 18.2600              22.2420
# LSTM_POLARITY                  -1.0000               1.0000
# TEXTBLOB_POLARITY               0.0000               0.0000
# LSTM_SENTIMENT                     NaN                  NaN
#
#                                    75%                  max             std
# ID                        677,443.7500         862,227.0000    247,562.4589
# TWEET                              NaN                  NaN             NaN
# STOCK                              NaN                  NaN             NaN
# DATE               2018-09-22 00:00:00  2018-10-31 00:00:00             NaN
# LAST_PRICE                  1,159.8300         165,500.0000      7,133.2535
# 1_DAY_RETURN                    0.0044               0.2340          0.0182
# 2_DAY_RETURN                    0.0097               0.2436          0.0226
# 3_DAY_RETURN                    0.0135               0.2436          0.0268
# 7_DAY_RETURN                    0.0261               0.2671          0.0422
# PX_VOLUME              25,924,569.0000     314,833,202.0000 20,390,217.0190
# VOLATILITY_10D                 27.2670             124.1370         17.5317
# VOLATILITY_30D                 27.3880              87.6850         12.2193
# LSTM_POLARITY                   1.0000               1.0000          0.9926
# TEXTBLOB_POLARITY               0.1500               1.0000          0.2610
# LSTM_SENTIMENT                     NaN                  NaN             NaN
#                    missing_count  missing_pct
# VOLATILITY_30D                45       0.0120
# TEXTBLOB_POLARITY              1       0.0000
#                    unique_count
# LSTM_POLARITY                 2
# LSTM_SENTIMENT                2
# STOCK                       101
# DATE                        121
# TEXTBLOB_POLARITY          3376
# VOLATILITY_30D             5615
# LAST_PRICE                 5618
# VOLATILITY_10D             5742
# 1_DAY_RETURN               5972
# PX_VOLUME                  6328
# 7_DAY_RETURN               6397
# 2_DAY_RETURN               7198
# 3_DAY_RETURN               8091
# TWEET                    206462
# ID                       367666
# Duplicate rows: 0
#
# Data types distribution:
# float64           10
# object             3
# int64              1
# datetime64[ns]     1
# Name: count, dtype: int64
# Parsed date/time candidates:
# C:\Users\owner\AppData\Local\Temp\ipykernel_24416\1910342420.py:111: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   parsed = pd.to_datetime(df[c], errors="coerce", infer_datetime_format=True)
# C:\Users\owner\AppData\Local\Temp\ipykernel_24416\1910342420.py:111: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   parsed = pd.to_datetime(df[c], errors="coerce", infer_datetime_format=True)
# C:\Users\owner\AppData\Local\Temp\ipykernel_24416\1910342420.py:111: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[c], errors="coerce", infer_datetime_format=True)
#      parsed_non_null                  min                  max
# DATE          367666  2017-01-31 00:00:00  2018-10-31 00:00:00
# Numeric columns (11): ['ID', 'LAST_PRICE', '1_DAY_RETURN', '2_DAY_RETURN', '3_DAY_RETURN', '7_DAY_RETURN', 'PX_VOLUME', 'VOLATILITY_10D', 'VOLATILITY_30D', 'LSTM_POLARITY', 'TEXTBLOB_POLARITY']
#                      skew
# LAST_PRICE        11.0057
# 1_DAY_RETURN       4.8636
# VOLATILITY_10D     3.3344
# 2_DAY_RETURN       2.4950
# VOLATILITY_30D     2.2353
# PX_VOLUME          2.1236
# 3_DAY_RETURN       1.7891
# 7_DAY_RETURN       1.3611
# TEXTBLOB_POLARITY  0.4946
# ID                -0.1105
# LSTM_POLARITY     -0.2440
# Categorical columns (3): ['TWEET', 'STOCK', 'LSTM_SENTIMENT']
#
# Top values for TWEET:
# TWEET
# RT @BTS_twt: RM - mono. Soundcloud: https://t.co/lRE59fNSls Google: https://t.co/OlW5N8xWa7 Mediafire: https://t.co/eatf17DRqR Dropbox: ht…         2619
# RT @darrenrovell: BREAKING: Nike had been paying Colin Kaepernick all along, waiting for the right moment. That moment is now, as he become…         956
# RT @Apple: The all-new iPhone XS, iPhone XS Max, iPhone XR and Apple Watch Series 4 are here. #AppleEvent                                            914
# RT @demitonight: Apple: Welcome iPhone XS others iPhones: https://t.co/miIunM17tv                                                                    771
# RT @PrettyRicc: Netflix would be better if it had: Suite life of Zack &amp; Cody Suite life on Deck Wizards of Waverly Place  Hannah Montana Th…     724
# RT @_itsB: Tf is Netflix sooo loud for when you first open it "DUH DOOM" head ass                                                                    717
# RT @thedonholly: If you plan on boycotting Nike I will dispose of all of your clothing items for FREE, just hit my DM’s. I have a school fu…         711
# RT @BigHitEnt: RM - 'mono.' Playlist Download Google: https://t.co/dv06I4DDj9 Mediafire: https://t.co/HUeJM6tkzS Dropbox: https://t.co/uMq…          706
# RT @Nobility_ofsoul: Let's settle this Netflix romcom war RT for Peter Kavinsky  Fav for Noah Flynn https://t.co/WfIzPbkxUc                          680
# RT @kennedybreann_: Biggest debate I have with anyone.. help a sister out 😅 RT for Spotify Premium Like for Apple Music                              670
# Name: count, dtype: int64
# Top values for STOCK:
# STOCK
# Ford         52198
# Facebook     40837
# Google       33697
# Next         32606
# Apple        27940
# Nike         27268
# Amazon       23994
# Netflix      18516
# Disney       13728
# Starbucks     6276
# Name: count, dtype: int64
# Top values for LSTM_SENTIMENT:
# LSTM_SENTIMENT
# Positive    206094
# Negative    161572
# Name: count, dtype: int64
# Saved missing_summary.csv and unique_counts.csv to eda_outputs/
#
# Random sample:
#              ID                                              TWEET    STOCK  \
# 1145950  721441  RT @businessinsider: The Audi e-tron all-elect...     Audi
# 437585   268103  Alienware 17 17.3in. (1TB, Intel Core i7 6th G...    Intel
# 128472    76067  RT @Apple: Introducing Apple Watch Series 4. F...    Apple
# 1032330  647627  U.S. charges North Korean hacker for cyber att...     Sony
# 141059    84188  RT @JohnWHuber: Number of times Dr. Ford has c...     Ford
# 977904   612940  RT @W_Angels_Wings: Daisy, Bold &amp; Beautifu...   Amazon
# 13241      7677  RT @Reuters: At least 15 killed, 300 wounded i...  Reuters
# 1071637  672538  RT @kimguilfoyle: Google Was "Working To Get H...   Google
# 1192714  752693  RT @frankthorp: In Maine radio interview, @Sen...     Ford
# 406201   248857  RT @princessssleah: Hate being under 4k balanc...   Amazon
#
#               DATE  LAST_PRICE  1_DAY_RETURN  2_DAY_RETURN  3_DAY_RETURN  \
# 1145950 2018-09-18    740.0000       -0.0054       -0.0135       -0.0135
# 437585  2017-11-01     46.7100       -0.0261       -0.0501       -0.0495
# 128472  2018-09-27    224.9500       -0.0201       -0.0123       -0.0185
# 1032330 2018-09-06  6,288.0000       -0.0086       -0.0016       -0.0019
# 141059  2018-10-01      9.3200       -0.0075       -0.0075       -0.0075
# 977904  2018-09-04  2,039.5100       -0.0131       -0.0131       -0.0131
# 13241   2017-05-31     48.0890        0.0034        0.0030        0.0030
# 1071637 2018-09-12  1,171.6000        0.0157        0.0030        0.0051
# 1192714 2018-09-20      9.8100       -0.0031       -0.0234       -0.0265
# 406201  2017-09-01    978.2500        0.0024       -0.0109       -0.0247
#
#          7_DAY_RETURN       PX_VOLUME  VOLATILITY_10D  VOLATILITY_30D  \
# 1145950       -0.0081         71.0000         36.4910         23.7790
# 437585        -0.1270 47,813,724.0000         36.8520         24.2600
# 128472        -0.0219 30,181,227.0000         22.9800         20.8110
# 1032330        0.0089  4,743,800.0000         16.9370         22.7090
# 141059         0.0290 44,864,717.0000         24.0130         22.4150
# 977904        -0.0523  5,721,093.0000         16.9000         20.5930
# 13241         -0.0011    928,465.0000         13.1330         20.0030
# 1071637        0.0235  1,785,833.0000         15.3950         16.7080
# 1192714       -0.0449 46,314,358.0000         12.6060         22.8260
# 406201        -0.0337  2,535,917.0000         15.6970         19.8600
#
#          LSTM_POLARITY  TEXTBLOB_POLARITY LSTM_SENTIMENT DATE_parsed
# 1145950        -1.0000             0.0000       Negative  2018-09-18
# 437585         -1.0000             0.0000       Negative  2017-11-01
# 128472         -1.0000             0.0000       Negative  2018-09-27
# 1032330         1.0000             0.0000       Positive  2018-09-06
# 141059          1.0000             0.0000       Positive  2018-10-01
# 977904         -1.0000             0.5917       Negative  2018-09-04
# 13241          -1.0000            -0.2500       Negative  2017-05-31
# 1071637        -1.0000             0.0000       Negative  2018-09-12
# 1192714        -1.0000             0.0222       Negative  2018-09-20
# 406201         -1.0000            -0.8000       Negative  2017-09-01
